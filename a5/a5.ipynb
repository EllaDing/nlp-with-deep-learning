# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/cs224n/a5
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs224n/a5

# %%
# !pip install -r gpu_requirements.txt

# %%
# !sh run.sh train
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 22, iter 147530, avg. loss 83.23, avg. ppl 64.38 cum. examples 48960, speed 5423.86 words/sec, time elapsed 16741.74 sec
# epoch 22, iter 147540, avg. loss 80.89, avg. ppl 65.40 cum. examples 49280, speed 5354.13 words/sec, time elapsed 16742.90 sec
# epoch 22, iter 147550, avg. loss 88.56, avg. ppl 80.12 cum. examples 49600, speed 5611.83 words/sec, time elapsed 16744.05 sec
# epoch 22, iter 147560, avg. loss 90.98, avg. ppl 85.54 cum. examples 49920, speed 6081.28 words/sec, time elapsed 16745.13 sec
# epoch 22, iter 147570, avg. loss 93.48, avg. ppl 75.44 cum. examples 50240, speed 5727.37 words/sec, time elapsed 16746.33 sec
# epoch 22, iter 147580, avg. loss 81.35, avg. ppl 67.50 cum. examples 50560, speed 6048.32 words/sec, time elapsed 16747.36 sec
# epoch 22, iter 147590, avg. loss 88.54, avg. ppl 82.36 cum. examples 50880, speed 6082.80 words/sec, time elapsed 16748.41 sec
# ...

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding:   0% 0/8064 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Decoding: 100% 8064/8064 [08:35<00:00, 15.65it/s]
# Corpus BLEU: 36.3728529806543
