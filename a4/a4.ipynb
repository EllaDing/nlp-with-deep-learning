# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/cs224n/a4
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs224n/a4

# %%
# !sh run.sh train
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 8, iter 51170, avg. loss 28.37, avg. ppl 3.92 cum. examples 37440, speed 3188.35 words/sec, time elapsed 10170.57 sec
# epoch 8, iter 51180, avg. loss 28.18, avg. ppl 3.77 cum. examples 37760, speed 3253.80 words/sec, time elapsed 10172.66 sec
# epoch 8, iter 51190, avg. loss 27.75, avg. ppl 3.92 cum. examples 38080, speed 3216.26 words/sec, time elapsed 10174.68 sec
# epoch 8, iter 51200, avg. loss 26.34, avg. ppl 3.64 cum. examples 38400, speed 3515.92 words/sec, time elapsed 10176.54 sec
# epoch 8, iter 51210, avg. loss 27.21, avg. ppl 3.65 cum. examples 38720, speed 3290.48 words/sec, time elapsed 10178.58 sec
# epoch 8, iter 51220, avg. loss 26.87, avg. ppl 3.87 cum. examples 39040, speed 3290.44 words/sec, time elapsed 10180.51 sec
# epoch 8, iter 51230, avg. loss 32.32, avg. ppl 4.25 cum. examples 39360, speed 3309.66 words/sec, time elapsed 10182.67 sec
# ...

# %%
# !sh run.sh test
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs224n/a4
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [11:51<00:00, 11.34it/s]
# Corpus BLEU: 35.8622829332315
